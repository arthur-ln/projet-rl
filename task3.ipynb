# %%
import gymnasium
import highway_env
from stable_baselines3 import DQN

from config.config_sb import config_dict

# %%
env = gymnasium.make("highway-fast-v0", render_mode="rgb_array")
env.unwrapped.configure(config_dict)


obs_space = env.observation_space
print(f"Observation space: {obs_space}")


obs, info = env.reset()
print(f"Observation shape: {obs.shape}")
# Out:
# Observation space: Box(-inf, inf, (5, 5), float32)
# Observation shape: (3, 3, 20)

# %%
model = DQN('MlpPolicy', env,
          policy_kwargs=dict(net_arch=[256, 256]),
          learning_rate=5e-4,
          buffer_size=15000,
          learning_starts=200,
          batch_size=32,
          gamma=0.8,
          train_freq=1,
          gradient_steps=1,
          target_update_interval=50,
          verbose=1,
          tensorboard_log="highway_dqn/")

model.learn(total_timesteps=2e4)
model.save("highway_dqn/model")

print("Model saved to highway_dqn/model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 146      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 146      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 145      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 231      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0676   |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 142      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 295      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0207   |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 141      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 394      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0683   |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 139      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 480      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0422   |
# |    n_updates        | 279      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 138      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 567      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0482   |
# |    n_updates        | 366      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 138      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 689      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0267   |
# |    n_updates        | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 137      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 765      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0347   |
# |    n_updates        | 564      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 137      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 858      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0902   |
# |    n_updates        | 657      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 136      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 980      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0415   |
# |    n_updates        | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 136      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 1039     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0189   |
# |    n_updates        | 838      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 135      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1194     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0214   |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.414    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 135      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 1233     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0428   |
# |    n_updates        | 1032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 136      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 1524     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0205   |
# |    n_updates        | 1323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 136      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 1660     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.016    |
# |    n_updates        | 1459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.6     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.0752   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 135      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1947     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0126   |
# |    n_updates        | 1746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 135      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 2274     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0448   |
# |    n_updates        | 2073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 135      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 2667     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0146   |
# |    n_updates        | 2466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 135      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 2942     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00903  |
# |    n_updates        | 2741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 34       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 135      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 3164     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0133   |
# |    n_updates        | 2963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.9     |
# |    ep_rew_mean      | 35.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 136      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 3422     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0134   |
# |    n_updates        | 3221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | 37       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 135      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 3741     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0113   |
# |    n_updates        | 3540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.3     |
# |    ep_rew_mean      | 37.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 134      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 3968     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0102   |
# |    n_updates        | 3767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.3     |
# |    ep_rew_mean      | 37.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 134      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 4126     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0121   |
# |    n_updates        | 3925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.8     |
# |    ep_rew_mean      | 39.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 133      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 4364     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00941  |
# |    n_updates        | 4163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.9     |
# |    ep_rew_mean      | 41.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 133      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 4628     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 4427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.5     |
# |    ep_rew_mean      | 43.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 132      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 4985     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00477  |
# |    n_updates        | 4784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 47       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 133      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 5385     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0163   |
# |    n_updates        | 5184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.2     |
# |    ep_rew_mean      | 49.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 133      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 5712     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00917  |
# |    n_updates        | 5511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.3     |
# |    ep_rew_mean      | 52.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 133      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 6112     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00497  |
# |    n_updates        | 5911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.6     |
# |    ep_rew_mean      | 54.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 133      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 6431     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 6230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.7     |
# |    ep_rew_mean      | 56.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 134      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 6757     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0192   |
# |    n_updates        | 6556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.1     |
# |    ep_rew_mean      | 59       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 134      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 7076     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00411  |
# |    n_updates        | 6875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64       |
# |    ep_rew_mean      | 59.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 134      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 7255     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0102   |
# |    n_updates        | 7054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.8     |
# |    ep_rew_mean      | 62.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 134      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 7655     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0102   |
# |    n_updates        | 7454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.2     |
# |    ep_rew_mean      | 65.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 134      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 7956     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00737  |
# |    n_updates        | 7755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.3     |
# |    ep_rew_mean      | 66.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 134      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 8226     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00567  |
# |    n_updates        | 8025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.3     |
# |    ep_rew_mean      | 69.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 134      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 8564     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0127   |
# |    n_updates        | 8363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.4     |
# |    ep_rew_mean      | 69.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 133      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 8867     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00653  |
# |    n_updates        | 8666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.9     |
# |    ep_rew_mean      | 70.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 133      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 9148     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00769  |
# |    n_updates        | 8947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | 72       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 133      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 9548     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00623  |
# |    n_updates        | 9347     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.9     |
# |    ep_rew_mean      | 71.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 133      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 9768     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00856  |
# |    n_updates        | 9567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.9     |
# |    ep_rew_mean      | 69.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 133      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 9956     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00753  |
# |    n_updates        | 9755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.8     |
# |    ep_rew_mean      | 70       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 133      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 10320    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0165   |
# |    n_updates        | 10119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.2     |
# |    ep_rew_mean      | 69.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 133      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 10484    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00637  |
# |    n_updates        | 10283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.1     |
# |    ep_rew_mean      | 69.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 133      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 10730    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0151   |
# |    n_updates        | 10529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.9     |
# |    ep_rew_mean      | 69.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 133      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 11030    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0161   |
# |    n_updates        | 10829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.4     |
# |    ep_rew_mean      | 69.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 133      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 11304    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00313  |
# |    n_updates        | 11103    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.1     |
# |    ep_rew_mean      | 71.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 133      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 11636    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0151   |
# |    n_updates        | 11435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.8     |
# |    ep_rew_mean      | 72.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 133      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 11945    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00999  |
# |    n_updates        | 11744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.7     |
# |    ep_rew_mean      | 71.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 133      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 12098    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0132   |
# |    n_updates        | 11897    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 70.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 133      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 12377    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0139   |
# |    n_updates        | 12176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 70.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 133      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 12777    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00813  |
# |    n_updates        | 12576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.1     |
# |    ep_rew_mean      | 70       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 133      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 13025    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00529  |
# |    n_updates        | 12824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.4     |
# |    ep_rew_mean      | 69.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 133      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 13354    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0079   |
# |    n_updates        | 13153    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.8     |
# |    ep_rew_mean      | 68.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 133      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 13610    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00871  |
# |    n_updates        | 13409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 69.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 134      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 14010    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00878  |
# |    n_updates        | 13809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.1     |
# |    ep_rew_mean      | 70.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 134      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 14383    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0033   |
# |    n_updates        | 14182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.8     |
# |    ep_rew_mean      | 70       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 134      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 14536    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00411  |
# |    n_updates        | 14335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 69.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 134      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 14907    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00543  |
# |    n_updates        | 14706    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.9     |
# |    ep_rew_mean      | 70.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 134      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 15249    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00259  |
# |    n_updates        | 15048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.4     |
# |    ep_rew_mean      | 70.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 134      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 15570    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0127   |
# |    n_updates        | 15369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 69.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 134      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 15793    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0274   |
# |    n_updates        | 15592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.3     |
# |    ep_rew_mean      | 70.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 134      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 16193    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0142   |
# |    n_updates        | 15992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 69.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 134      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 16379    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0034   |
# |    n_updates        | 16178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | 68.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 134      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 16645    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00383  |
# |    n_updates        | 16444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.8     |
# |    ep_rew_mean      | 69.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 134      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 16951    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0044   |
# |    n_updates        | 16750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 70       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 134      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 17206    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00466  |
# |    n_updates        | 17005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 69.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 134      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 17470    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0436   |
# |    n_updates        | 17269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 71.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 134      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 17870    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00386  |
# |    n_updates        | 17669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.4     |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 134      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 18270    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000956 |
# |    n_updates        | 18069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | 73.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 134      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 18632    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 18431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | 73.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 134      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 18861    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00606  |
# |    n_updates        | 18660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.1     |
# |    ep_rew_mean      | 71.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 134      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 19048    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00367  |
# |    n_updates        | 18847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.7     |
# |    ep_rew_mean      | 71.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 134      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 19313    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00676  |
# |    n_updates        | 19112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.2     |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 134      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 19414    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00496  |
# |    n_updates        | 19213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73       |
# |    ep_rew_mean      | 70.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 134      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 19674    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0319   |
# |    n_updates        | 19473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.3     |
# |    ep_rew_mean      | 68       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 134      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 19805    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00872  |
# |    n_updates        | 19604    |
# ----------------------------------
# Model saved to highway_dqn/model

# %%
model = DQN.load("highway_dqn/model")

episodes = 100
for episode in range(episodes):
    done = truncated = False
    obs, info = env.reset()
    episode_reward = 0
    
    while not (done or truncated):
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(action)
        episode_reward += reward
        env.render()
    
    print(f"Episode {episode+1}: Reward = {episode_reward}")
# Out:
# Episode 1: Reward = 95.12864105740587
# Episode 2: Reward = 16.649436275087915
# Episode 3: Reward = 14.934616967000284
# Episode 4: Reward = 3.079821521900746
# Episode 5: Reward = 99.07750561487074
# Episode 6: Reward = 97.18092789170863
# Episode 7: Reward = 99.44901352761181
# Episode 8: Reward = 6.004236555965546
# Episode 9: Reward = 96.46436048654517
# Episode 10: Reward = 5.059160714323233
# Episode 11: Reward = 30.24890606698977
# Episode 12: Reward = 96.2437311132718
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 13
#      11     obs, reward, done, truncated, info = env.step(action)
#      12     episode_reward += reward
# ---> 13     env.render()
#      15 print(f"Episode {episode+1}: Reward = {episode_reward}")
#
# File /opt/anaconda3/envs/pytorch-mps/lib/python3.12/site-packages/gymnasium/wrappers/common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File /opt/anaconda3/envs/pytorch-mps/lib/python3.12/site-packages/gymnasium/core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File /opt/anaconda3/envs/pytorch-mps/lib/python3.12/site-packages/gymnasium/wrappers/common.py:303, in PassiveEnvChecker.render(self)
#     301     return env_render_passive_checker(self.env)
#     302 else:
# --> 303     return self.env.render()
#
# File /opt/anaconda3/envs/pytorch-mps/lib/python3.12/site-packages/highway_env/envs/common/abstract.py:308, in AbstractEnv.render(self)
#     306     self.viewer.handle_events()
#     307 if self.render_mode == "rgb_array":
# --> 308     image = self.viewer.get_image()
#     309     return image
#
# AttributeError: 'NoneType' object has no attribute 'get_image'
