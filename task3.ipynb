# %% [markdown]
# ## Import des librairies

# %%
import gymnasium
import highway_env
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# ## Configuration de l'environnement

# %%
# Configuration de style pour les graphiques
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 8)
plt.rcParams["font.size"] = 12

# Création du répertoire pour les logs et les modèles sauvegardés
log_dir = "highway_dqn_logs/"
model_dir = "highway_dqn_models/"
os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)

# Importation de la configuration spécifique à l'environnement
from config.config_sb import config_dict

# %% [markdown]
# ## Fonctions Utiles

# %%
# Callback personnalisé pour suivre l'apprentissage
class TrainingMonitorCallback(BaseCallback):
    def __init__(self, check_freq=1000, save_path=None, verbose=1):
        super(TrainingMonitorCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        self.rewards_history = []
        self.episode_lengths = []
        self.current_episode_reward = 0
        self.current_episode_length = 0
        self.collision_count = 0
        self.lane_changes = 0
        self.speeds = []

    def _on_step(self):
        # Récupérer les informations de l'étape actuelle
        info = (
            self.locals.get("infos")[0] if "infos" in self.locals else {}
        )
        reward = self.locals.get("rewards")[0] if "rewards" in self.locals else 0
        done = self.locals.get("dones")[0] if "dones" in self.locals else False

        # Incrémenter les compteurs d'épisode
        self.current_episode_reward += reward
        self.current_episode_length += 1

        # Collecter des statistiques de conduite si disponibles
        if isinstance(info, dict):
            # Adaptation pour la nouvelle structure d'info
            if "speed" in info:
                self.speeds.append(info["speed"])
            if "crashed" in info and info["crashed"]:
                self.collision_count += 1
            if "action" in info:
                action = info["action"]
                if isinstance(action, np.ndarray) and action.size == 1:
                    action = action.item()
                if action in [0, 2]:
                    self.lane_changes += 1

        # À la fin d'un épisode, enregistrer les statistiques et réinitialiser
        if done:
            self.rewards_history.append(self.current_episode_reward)
            self.episode_lengths.append(self.current_episode_length)
            self.current_episode_reward = 0
            self.current_episode_length = 0

        # Sauvegarder le modèle périodiquement
        if self.n_calls % self.check_freq == 0 and self.save_path is not None:
            path = os.path.join(self.save_path, f"model_{self.n_calls}_steps")
            self.model.save(path)
            if self.verbose > 0:
                print(f"Model saved to {path}")

            # Générer et sauvegarder des graphiques d'apprentissage
            self._plot_training_progress()

        return True

    def _plot_training_progress(self):
        """Génère des graphiques montrant la progression de l'apprentissage"""
        # Vérifier s'il y a des données à tracer
        if not self.rewards_history:
            return
        # Récompenses par épisode
        plt.figure(figsize=(15, 10))

        # Subplot pour les récompenses
        plt.subplot(2, 2, 1)
        plt.plot(self.rewards_history, label="Récompense par épisode")
        if len(self.rewards_history) >= 10:  # Seulement si assez de données
            plt.plot(
                pd.Series(self.rewards_history).rolling(10).mean(),
                label="Moyenne mobile (10 épisodes)",
            )
        plt.xlabel("Épisode")
        plt.ylabel("Récompense cumulée")
        plt.title("Évolution des récompenses pendant l'apprentissage")
        plt.legend()
        plt.grid(True)

        # Subplot pour la durée des épisodes
        plt.subplot(2, 2, 2)
        plt.plot(self.episode_lengths)
        plt.xlabel("Épisode")
        plt.ylabel("Nombre de pas")
        plt.title("Durée des épisodes pendant l'apprentissage")
        plt.grid(True)

        # Subplot pour les collisions
        if len(self.rewards_history) > 0:
            collision_rate = self.collision_count / len(self.rewards_history)
            plt.subplot(2, 2, 3)
            plt.bar(["Taux de collision"], [collision_rate])
            plt.ylabel("Collisions par épisode")
            plt.title(f"Taux de collision: {collision_rate:.4f}")

        # Subplot pour la distribution des vitesses
        if len(self.speeds) > 0:
            plt.subplot(2, 2, 4)
            sns.histplot(self.speeds, kde=True)
            plt.xlabel("Vitesse")
            plt.title("Distribution des vitesses")

        plt.tight_layout()
        plt.savefig(
            os.path.join(self.save_path, f"training_progress_{self.n_calls}.png")
        )
        plt.close()


# Fonction pour évaluer le modèle entraîné
def evaluate_and_visualize(model, env, num_episodes=10, display = False):
    """Évalue le modèle et génère des visualisations sur ses performances"""
    # Variables pour collecter les statistiques
    rewards = []
    episode_lengths = []
    speeds = []
    actions = []  # Stockage des actions au lieu des positions de voie
    collisions = 0
    lane_changes = 0

    # Collecter des statistiques détaillées
    for episode in range(num_episodes):
        done = truncated = False
        obs, info = env.reset()
        episode_reward = 0
        episode_length = 0
        episode_speeds = []
        episode_actions = []

        while not (done or truncated):
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, truncated, info = env.step(action)

            # Collecte de statistiques
            episode_reward += reward
            episode_length += 1

            if isinstance(info, dict):
                if "speed" in info:
                    episode_speeds.append(info["speed"])
                if "action" in info:
                    a = info["action"]
                    if isinstance(a, np.ndarray) and a.size == 1:
                        a = a.item()
                    episode_actions.append(a)
                    if a in [0, 2]:  # Actions de changement de voie
                        lane_changes += 1
                if "crashed" in info and info["crashed"]:
                    collisions += 1
                    
                if display == True :
                    env.render()  # Rendu de l'environnement pour visualisation

        # Enregistrer les statistiques de l'épisode
        rewards.append(episode_reward)
        episode_lengths.append(episode_length)
        speeds.extend(episode_speeds)
        actions.extend(episode_actions)

        print(
            f"Épisode {episode+1}: Récompense = {episode_reward:.2f}, Durée = {episode_length}"
        )

    # Créer des visualisations pour le rapport
    create_evaluation_visualizations(
        rewards,
        episode_lengths,
        speeds,
        actions,  # Utilisation des actions au lieu des voies
        collisions / num_episodes,
        lane_changes / num_episodes,
    )

    return np.mean(rewards), np.std(rewards)


def create_evaluation_visualizations(
    rewards, lengths, speeds, actions, collision_rate, lane_change_rate
):
    """Crée des visualisations détaillées sur les performances du modèle"""
    # Vérifier si des données sont disponibles
    if not rewards:
        print("Pas de données d'évaluation disponibles pour créer des visualisations")
        return

    # Configurer une figure avec plusieurs sous-graphiques
    plt.figure(figsize=(15, 12))

    # 1. Distribution des récompenses par épisode
    plt.subplot(2, 3, 1)
    sns.barplot(x=list(range(1, len(rewards) + 1)), y=rewards)
    plt.xlabel("Épisode")
    plt.ylabel("Récompense totale")
    plt.title("Récompenses par épisode")

    # 2. Distribution des durées d'épisode
    plt.subplot(2, 3, 2)
    sns.barplot(x=list(range(1, len(lengths) + 1)), y=lengths)
    plt.xlabel("Épisode")
    plt.ylabel("Nombre de pas")
    plt.title("Durée des épisodes")

    # 3. Distribution des vitesses
    plt.subplot(2, 3, 3)
    if speeds:
        sns.histplot(speeds, kde=True)
        plt.xlabel("Vitesse")
        plt.ylabel("Fréquence")
        plt.title("Distribution des vitesses")
    else:
        plt.text(
            0.5, 0.5, "Pas de données de vitesse disponibles", ha="center", va="center"
        )
        plt.axis("off")

    # 4. Distribution des actions
    plt.subplot(2, 3, 4)
    if actions:
        # Comptage des actions
        action_counts = pd.Series(actions).value_counts().sort_index()
        action_names = {
            0: "LANE_LEFT",
            1: "IDLE",
            2: "LANE_RIGHT",
            3: "FASTER",
            4: "SLOWER"
        }
        
        # Pour les indices existants uniquement
        labels = [action_names.get(i, f"Action {i}") for i in action_counts.index]
        
        sns.barplot(x=labels, y=action_counts.values)
        plt.xlabel("Action")
        plt.ylabel("Fréquence")
        plt.title("Distribution des actions")
        plt.xticks(rotation=45)
    else:
        plt.text(
            0.5, 0.5, "Pas de données d'action disponibles", ha="center", va="center"
        )
        plt.axis("off")

    # 5. Affichage des taux de collision et de changement de voie
    plt.subplot(2, 3, 5)
    rates = [collision_rate, lane_change_rate]
    print(f"Taux de collision: {collision_rate:.4f}, Taux de demande de changement de voie: {lane_change_rate:.4f}")
    labels = ["Taux de collision", "Taux de changement de voie"]
    sns.barplot(x=labels, y=rates)
    plt.ylabel("Taux par épisode")
    plt.title("Statistiques de conduite")

    plt.tight_layout()
    plt.savefig(os.path.join(log_dir, "evaluation_results.png"), dpi=300)
    plt.close()

    # Créer un graphique séparé pour l'analyse de la politique si suffisamment de données
    if speeds and len(rewards) > 5:
        create_policy_analysis(rewards, speeds, actions, collision_rate)


def create_policy_analysis(rewards, speeds, actions, collision_rate):
    """Crée une visualisation analysant la politique apprise"""
    plt.figure(figsize=(12, 6))

    # Relation entre vitesse moyenne et récompense par épisode
    if len(rewards) > 5:
        avg_speeds = []
        for i in range(len(rewards)):
            start = i * (len(speeds) // len(rewards))
            end = (
                (i + 1) * (len(speeds) // len(rewards))
                if i < len(rewards) - 1
                else len(speeds)
            )
            if start < len(speeds) and end <= len(speeds) and start < end:
                avg_speeds.append(np.mean(speeds[start:end]))
            else:
                avg_speeds.append(0)  # Valeur par défaut si l'indice est hors limite

        plt.scatter(avg_speeds, rewards, s=100, alpha=0.7)

        # Ajouter une ligne de tendance
        z = np.polyfit(avg_speeds, rewards, 1)
        p = np.poly1d(z)
        plt.plot(sorted(avg_speeds), p(sorted(avg_speeds)), "r--", alpha=0.8)

        plt.xlabel("Vitesse moyenne par épisode")
        plt.ylabel("Récompense totale par épisode")
        plt.title("Relation entre vitesse et récompense (politique apprise)")
        plt.grid(True)

    plt.tight_layout()
    plt.savefig(os.path.join(log_dir, "policy_analysis.png"), dpi=300)
    plt.close()

    # Ajout d'un graphique pour analyser les composantes de récompense
    plt.figure(figsize=(12, 6))
    
    plt.text(0.5, 0.5, 
             f"Analyse des performances:\n\n"
             f"Taux de collision: {collision_rate:.4f} par épisode\n"
             f"Vitesse moyenne: {np.mean(speeds):.2f}\n"
             f"Récompense moyenne: {np.mean(rewards):.2f}",
             ha="center", va="center", fontsize=12)
    plt.axis("off")
    plt.tight_layout()
    plt.savefig(os.path.join(log_dir, "reward_components_analysis.png"), dpi=300)
    plt.close()


def plot_training_rewards(rewards_history):
    """Trace la courbe des récompenses d'apprentissage"""
    if not rewards_history:
        print("Pas de données d'entraînement disponibles pour créer des visualisations")
        return

    plt.figure(figsize=(12, 6))
    # plt.plot(rewards_history, label="Récompense par épisode")

    # Ajouter une moyenne mobile si suffisamment de données
    if len(rewards_history) >= 10:
        window_size = max(5, len(rewards_history) // 20)
        smoothed_rewards = pd.Series(rewards_history).rolling(window=window_size).mean()
        plt.plot(
            smoothed_rewards,
            "r-",
            linewidth=2,
            label=f"Moyenne mobile ({window_size} épisodes)",
        )

    plt.xlabel("Épisode")
    plt.ylabel("Récompense cumulée")
    plt.title("Courbe d'apprentissage")
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.savefig(os.path.join(log_dir, "learning_curve.png"), dpi=300)
    plt.close()

# %% [markdown]
# ## Initialisation de l'environnement

# %%
# Créer et configurer l'environnement
env = gymnasium.make("highway-fast-v0", render_mode="rgb_array")
env.unwrapped.configure(config_dict)

# Wrapper l'environnement avec Monitor pour enregistrer les statistiques
env = Monitor(env, log_dir)

# Afficher les informations sur l'espace d'observation
obs_space = env.observation_space
print(f"Espace d'observation: {obs_space}")

# Tester l'environnement
obs, info = env.reset()
print(f"Forme de l'observation: {obs.shape}")
print(f"Exemple d'info: {info}")
# Out:
# Espace d'observation: Box(-inf, inf, (5, 5), float32)
# Forme de l'observation: (3, 3, 20)
# Exemple d'info: {'speed': 25, 'crashed': False, 'action': 1, 'rewards': {'collision_reward': 0.0, 'right_lane_reward': 1.0, 'high_speed_reward': 0.7, 'on_road_reward': 1.0}}

# %% [markdown]
# ## Entraînement

# %%
# Initialiser le callback pour le suivi de l'apprentissage
callback = TrainingMonitorCallback(check_freq=1000, save_path=model_dir, verbose=1)

# Créer et entraîner le modèle DQN
model = DQN(
    "MlpPolicy",
    env,
    policy_kwargs=dict(net_arch=[256, 256]),
    learning_rate=5e-4,
    buffer_size=15000,
    learning_starts=200,
    batch_size=32,
    gamma=0.8,
    train_freq=1,
    gradient_steps=1,
    target_update_interval=50,
    verbose=1,
    tensorboard_log=None,
)

# Entraîner le modèle avec le callback personnalisé
model.learn(total_timesteps=20000, callback=callback)

# Sauvegarder le modèle final
final_model_path = os.path.join(model_dir, "model_final")
model.save(final_model_path)
print(f"Modèle final sauvegardé à {final_model_path}")

# Tracer la courbe d'apprentissage à partir des données collectées
plot_training_rewards(callback.rewards_history)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.8     |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 31       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.1     |
# |    ep_rew_mean      | 35.8     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 25       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 329      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0511   |
# |    n_updates        | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.7     |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 24       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 392      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0439   |
# |    n_updates        | 191      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | 28.6     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 22       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 527      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0925   |
# |    n_updates        | 326      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32       |
# |    ep_rew_mean      | 28       |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 20       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 641      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0324   |
# |    n_updates        | 440      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.3     |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 20       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 776      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0163   |
# |    n_updates        | 575      |
# ----------------------------------
# Model saved to highway_dqn_models/model_1000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.7     |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 19       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 1000     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0182   |
# |    n_updates        | 799      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 19       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 1122     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0264   |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 34.9     |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 19       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 1258     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0442   |
# |    n_updates        | 1057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 19       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 1503     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0158   |
# |    n_updates        | 1302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.6     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 19       |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 1697     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0128   |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.5     |
# |    ep_rew_mean      | 37.3     |
# |    exploration_rate | 0.0547   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 19       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 1990     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0253   |
# |    n_updates        | 1789     |
# ----------------------------------
# Model saved to highway_dqn_models/model_2000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.6     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 19       |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 2060     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0349   |
# |    n_updates        | 1859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.8     |
# |    ep_rew_mean      | 35.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 19       |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 2231     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00687  |
# |    n_updates        | 2030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.9     |
# |    ep_rew_mean      | 39       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 19       |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 2575     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.015    |
# |    n_updates        | 2374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.9     |
# |    ep_rew_mean      | 41.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 19       |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 2938     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00735  |
# |    n_updates        | 2737     |
# ----------------------------------
# Model saved to highway_dqn_models/model_3000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.1     |
# |    ep_rew_mean      | 43.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 19       |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 3270     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00664  |
# |    n_updates        | 3069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51       |
# |    ep_rew_mean      | 46.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 18       |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 3670     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0164   |
# |    n_updates        | 3469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.4     |
# |    ep_rew_mean      | 46.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 18       |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 3903     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0519   |
# |    n_updates        | 3702     |
# ----------------------------------
# Model saved to highway_dqn_models/model_4000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 47.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 18       |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 4172     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00932  |
# |    n_updates        | 3971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 48.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 18       |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 4475     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00821  |
# |    n_updates        | 4274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.6     |
# |    ep_rew_mean      | 48.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 18       |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 4715     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0119   |
# |    n_updates        | 4514     |
# ----------------------------------
# Model saved to highway_dqn_models/model_5000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55       |
# |    ep_rew_mean      | 50.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 18       |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 5058     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0133   |
# |    n_updates        | 4857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.2     |
# |    ep_rew_mean      | 50.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 18       |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 5303     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00562  |
# |    n_updates        | 5102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.1     |
# |    ep_rew_mean      | 51.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 18       |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 5607     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00477  |
# |    n_updates        | 5406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.9     |
# |    ep_rew_mean      | 53       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 18       |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 5937     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00715  |
# |    n_updates        | 5736     |
# ----------------------------------
# Model saved to highway_dqn_models/model_6000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 59.1     |
# |    ep_rew_mean      | 54.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 18       |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 6241     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0106   |
# |    n_updates        | 6040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.4     |
# |    ep_rew_mean      | 56.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 19       |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 6528     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00871  |
# |    n_updates        | 6327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64       |
# |    ep_rew_mean      | 58.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 19       |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 6928     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00421  |
# |    n_updates        | 6727     |
# ----------------------------------
# Model saved to highway_dqn_models/model_7000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.8     |
# |    ep_rew_mean      | 60.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 19       |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 7218     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0134   |
# |    n_updates        | 7017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 62.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 19       |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 7578     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0145   |
# |    n_updates        | 7377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.1     |
# |    ep_rew_mean      | 62.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 19       |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 7707     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.019    |
# |    n_updates        | 7506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.1     |
# |    ep_rew_mean      | 63.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 19       |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 7931     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00532  |
# |    n_updates        | 7730     |
# ----------------------------------
# Model saved to highway_dqn_models/model_8000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.2     |
# |    ep_rew_mean      | 64.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 19       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 8180     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0191   |
# |    n_updates        | 7979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.8     |
# |    ep_rew_mean      | 64.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 19       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 8482     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00695  |
# |    n_updates        | 8281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | 66.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 19       |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 8814     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0058   |
# |    n_updates        | 8613     |
# ----------------------------------
# Model saved to highway_dqn_models/model_9000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | 66.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 19       |
# |    time_elapsed     | 469      |
# |    total_timesteps  | 9110     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00471  |
# |    n_updates        | 8909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72       |
# |    ep_rew_mean      | 67.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 19       |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 9263     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0792   |
# |    n_updates        | 9062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 67.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 19       |
# |    time_elapsed     | 484      |
# |    total_timesteps  | 9486     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00692  |
# |    n_updates        | 9285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 66.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 19       |
# |    time_elapsed     | 493      |
# |    total_timesteps  | 9724     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0063   |
# |    n_updates        | 9523     |
# ----------------------------------
# Model saved to highway_dqn_models/model_10000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | 66.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 19       |
# |    time_elapsed     | 505      |
# |    total_timesteps  | 10039    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00511  |
# |    n_updates        | 9838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | 66.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 20       |
# |    time_elapsed     | 517      |
# |    total_timesteps  | 10374    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0496   |
# |    n_updates        | 10173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.2     |
# |    ep_rew_mean      | 64.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 20       |
# |    time_elapsed     | 524      |
# |    total_timesteps  | 10589    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00597  |
# |    n_updates        | 10388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | 66.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 20       |
# |    time_elapsed     | 538      |
# |    total_timesteps  | 10989    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00771  |
# |    n_updates        | 10788    |
# ----------------------------------
# Model saved to highway_dqn_models/model_11000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.5     |
# |    ep_rew_mean      | 66.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 20       |
# |    time_elapsed     | 548      |
# |    total_timesteps  | 11221    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0876   |
# |    n_updates        | 11020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.7     |
# |    ep_rew_mean      | 66.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 20       |
# |    time_elapsed     | 561      |
# |    total_timesteps  | 11541    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00972  |
# |    n_updates        | 11340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.7     |
# |    ep_rew_mean      | 67.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 20       |
# |    time_elapsed     | 574      |
# |    total_timesteps  | 11884    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0832   |
# |    n_updates        | 11683    |
# ----------------------------------
# Model saved to highway_dqn_models/model_12000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 68.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 20       |
# |    time_elapsed     | 593      |
# |    total_timesteps  | 12284    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0351   |
# |    n_updates        | 12083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.6     |
# |    ep_rew_mean      | 69.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 20       |
# |    time_elapsed     | 607      |
# |    total_timesteps  | 12660    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0122   |
# |    n_updates        | 12459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.6     |
# |    ep_rew_mean      | 69.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 20       |
# |    time_elapsed     | 619      |
# |    total_timesteps  | 12965    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0047   |
# |    n_updates        | 12764    |
# ----------------------------------
# Model saved to highway_dqn_models/model_13000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.7     |
# |    ep_rew_mean      | 68.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 20       |
# |    time_elapsed     | 631      |
# |    total_timesteps  | 13203    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00548  |
# |    n_updates        | 13002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 68.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 21       |
# |    time_elapsed     | 640      |
# |    total_timesteps  | 13468    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00235  |
# |    n_updates        | 13267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 68.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 21       |
# |    time_elapsed     | 652      |
# |    total_timesteps  | 13776    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0014   |
# |    n_updates        | 13575    |
# ----------------------------------
# Model saved to highway_dqn_models/model_14000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.4     |
# |    ep_rew_mean      | 67.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 21       |
# |    time_elapsed     | 666      |
# |    total_timesteps  | 14069    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00609  |
# |    n_updates        | 13868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 68       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 21       |
# |    time_elapsed     | 681      |
# |    total_timesteps  | 14373    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00794  |
# |    n_updates        | 14172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.3     |
# |    ep_rew_mean      | 66.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 21       |
# |    time_elapsed     | 690      |
# |    total_timesteps  | 14607    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00633  |
# |    n_updates        | 14406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 69       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 21       |
# |    time_elapsed     | 704      |
# |    total_timesteps  | 14952    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0604   |
# |    n_updates        | 14751    |
# ----------------------------------
# Model saved to highway_dqn_models/model_15000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.2     |
# |    ep_rew_mean      | 70.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 21       |
# |    time_elapsed     | 720      |
# |    total_timesteps  | 15352    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00493  |
# |    n_updates        | 15151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.8     |
# |    ep_rew_mean      | 71.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 21       |
# |    time_elapsed     | 734      |
# |    total_timesteps  | 15662    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00436  |
# |    n_updates        | 15461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.9     |
# |    ep_rew_mean      | 71.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 21       |
# |    time_elapsed     | 750      |
# |    total_timesteps  | 15970    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00982  |
# |    n_updates        | 15769    |
# ----------------------------------
# Model saved to highway_dqn_models/model_16000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | 72.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 21       |
# |    time_elapsed     | 768      |
# |    total_timesteps  | 16370    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00457  |
# |    n_updates        | 16169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.8     |
# |    ep_rew_mean      | 72.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 21       |
# |    time_elapsed     | 780      |
# |    total_timesteps  | 16692    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0639   |
# |    n_updates        | 16491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.4     |
# |    ep_rew_mean      | 73       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 21       |
# |    time_elapsed     | 787      |
# |    total_timesteps  | 16905    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00533  |
# |    n_updates        | 16704    |
# ----------------------------------
# Model saved to highway_dqn_models/model_17000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | 73.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 21       |
# |    time_elapsed     | 797      |
# |    total_timesteps  | 17173    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00404  |
# |    n_updates        | 16972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | 72.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 21       |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 17281    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00435  |
# |    n_updates        | 17080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.4     |
# |    ep_rew_mean      | 73.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 21       |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 17681    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00946  |
# |    n_updates        | 17480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.5     |
# |    ep_rew_mean      | 71.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 21       |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 17820    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00476  |
# |    n_updates        | 17619    |
# ----------------------------------
# Model saved to highway_dqn_models/model_18000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75       |
# |    ep_rew_mean      | 71.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 21       |
# |    time_elapsed     | 837      |
# |    total_timesteps  | 18090    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00252  |
# |    n_updates        | 17889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.2     |
# |    ep_rew_mean      | 70.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 21       |
# |    time_elapsed     | 849      |
# |    total_timesteps  | 18304    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 18103    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.1     |
# |    ep_rew_mean      | 71       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 21       |
# |    time_elapsed     | 864      |
# |    total_timesteps  | 18634    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00439  |
# |    n_updates        | 18433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74       |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 21       |
# |    time_elapsed     | 877      |
# |    total_timesteps  | 18937    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00719  |
# |    n_updates        | 18736    |
# ----------------------------------
# Model saved to highway_dqn_models/model_19000_steps
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.6     |
# |    ep_rew_mean      | 70.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 21       |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 19248    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00363  |
# |    n_updates        | 19047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.9     |
# |    ep_rew_mean      | 69.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 21       |
# |    time_elapsed     | 897      |
# |    total_timesteps  | 19571    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00321  |
# |    n_updates        | 19370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.7     |
# |    ep_rew_mean      | 69.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 21       |
# |    time_elapsed     | 914      |
# |    total_timesteps  | 19925    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00524  |
# |    n_updates        | 19724    |
# ----------------------------------
# Model saved to highway_dqn_models/model_20000_steps
# Modèle final sauvegardé à highway_dqn_models/model_final

# %% [markdown]
# ## Évaluation

# %%
# Évaluer et visualiser les performances du modèle final
print("\nÉvaluation du modèle final:")
# Il faut ajuster la valeur de Display pour afficher ou non l'environnement
display = True
mean_reward, std_reward = evaluate_and_visualize(model, env, num_episodes=100, display = display)
print(f"Récompense moyenne: {mean_reward:.2f} ± {std_reward:.2f}")

# Fermer l'environnement
env.close()

# %% [markdown]
# ## Exemple sur 3 épisodes

# %%
from IPython.display import HTML

# Remplace le chemin par celui de ta vidéo
video_path = "evaluation_video.mp4"

HTML(f'<video width="600" controls><source src="{video_path}" type="video/mp4"></video>')
# Out:
# <video width="600" controls><source src="evaluation_video.mp4" type="video/mp4"></video>
